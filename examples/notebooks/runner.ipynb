# %%
import air.compiler.util

from air.mlir.dialects import func
from air.mlir.dialects import linalg
from air.mlir.ir import *
import air.mlir.passmanager

import sys

# %%
def matmul_on_tensors(m, n, k, dtype):
    module = Module.create()
    with InsertionPoint(module.body):
        @func.FuncOp.from_py_func(
            RankedTensorType.get((m, k), dtype), RankedTensorType.get((k, n), dtype),
            RankedTensorType.get((m, n), dtype))
        def matmul(lhs, rhs, out):
            linalg.matmul(lhs, rhs, outs=[out])
    return module

# %%
with air.mlir.ir.Context(), Location.unknown():

    air_module = matmul_on_tensors(512, 512, 512, BF16Type.get())
    
    # convert linalg on tensors to linalg on memrefs
    pm = air.mlir.passmanager.PassManager.parse(air.compiler.util.LINALG_TENSOR_TO_MEMREF_PIPELINE)
    pm.run(air_module)

    # tile and map to air
    pipeline = ",".join([
        "air-linalg-codegen{l1-tile-size=32,32,32 l1-promote=true l2-tile-size=64,64,64 l2-promote=true}",
        "air-par-to-herd{depth=1}",
        "air-copy-to-dma",
        "canonicalize", "cse",
    ])
    pm = air.mlir.passmanager.PassManager.parse(pipeline)
    pm.run(air_module)
    
    #print ("\nAIR Dialect Module\n")
    #print (air_module)

    # generate dependency information for runner
    pm = air.mlir.passmanager.PassManager.parse("air-dependency,canonicalize,cse")
    pm.run(air_module)

    print ("\nAIR Dialect Module (async)\n")
    print (air_module)
# Out:
# AIR Dialect Module (async)
#
# #map = affine_map<()[s0] -> (s0 * 32)>
# module {
#   func.func @matmul(%arg0: memref<512x512xbf16>, %arg1: memref<512x512xbf16>, %arg2: memref<512x512xbf16>) {
#     %c1 = arith.constant 1 : index
#     %c2 = arith.constant 2 : index
#     %c64 = arith.constant 64 : index
#     %c512 = arith.constant 512 : index
#     %c0 = arith.constant 0 : index
#     %asyncToken, %valOut = air.execute async  {
#       %1 = memref.alloc() {alignment = 128 : i64} : memref<512x512xbf16>
#       air.execute_terminator %1 : memref<512x512xbf16>
#     } {id = 1 : i32} : (memref<512x512xbf16>)
#     %asyncToken_0 = air.execute async [%asyncToken]  : (!air.async.token) {
#       memref.copy %arg2, %valOut : memref<512x512xbf16> to memref<512x512xbf16>
#       air.execute_terminator
#     } {id = 2 : i32}
#     %0 = scf.parallel (%arg3, %arg4) = (%c0, %c0) to (%c512, %c512) step (%c64, %c64) init (%asyncToken_0) -> !air.async.token {
#       %1 = scf.for %arg5 = %c0 to %c512 step %c64 iter_args(%arg6 = %asyncToken_0) -> (!air.async.token) {
#         %asyncToken_1, %valOut_2 = air.execute async [%arg6]  : (!air.async.token) {
#           %8 = memref.alloc() : memref<64x64xbf16, 1>
#           air.execute_terminator %8 : memref<64x64xbf16, 1>
#         } {id = 3 : i32} : (memref<64x64xbf16, 1>)
#         %asyncToken_3, %valOut_4 = air.execute async [%arg6]  : (!air.async.token) {
#           %8 = memref.alloc() : memref<64x64xbf16, 1>
#           air.execute_terminator %8 : memref<64x64xbf16, 1>
#         } {id = 4 : i32} : (memref<64x64xbf16, 1>)
#         %asyncToken_5, %valOut_6 = air.execute async [%arg6]  : (!air.async.token) {
#           %8 = memref.alloc() : memref<64x64xbf16, 1>
#           air.execute_terminator %8 : memref<64x64xbf16, 1>
#         } {id = 5 : i32} : (memref<64x64xbf16, 1>)
#         %2 = air.dma_memcpy_nd async [%asyncToken_1] (%valOut_2[] [] [], %arg0[%arg3, %arg5] [%c64, %c64] [%c512, %c1]) {id = 1 : i32} : (memref<64x64xbf16, 1>, memref<512x512xbf16>)
#         %3 = air.dma_memcpy_nd async [%asyncToken_3] (%valOut_4[] [] [], %arg1[%arg5, %arg4] [%c64, %c64] [%c512, %c1]) {id = 2 : i32} : (memref<64x64xbf16, 1>, memref<512x512xbf16>)
#         %4 = air.dma_memcpy_nd async [%asyncToken_5, %arg6] (%valOut_6[] [] [], %valOut[%arg3, %arg4] [%c64, %c64] [%c512, %c1]) {id = 3 : i32} : (memref<64x64xbf16, 1>, memref<512x512xbf16>)
#         %5 = air.herd @herd_0 async [%3, %2, %4]  tile (%arg7, %arg8) in (%arg9=%c2, %arg10=%c2) args(%arg11=%valOut_2, %arg12=%valOut_4, %arg13=%valOut_6) : memref<64x64xbf16, 1>, memref<64x64xbf16, 1>, memref<64x64xbf16, 1> attributes {id = 1 : i32} {
#           %c1_10 = arith.constant 1 : index
#           %c0_11 = arith.constant 0 : index
#           %c64_12 = arith.constant 64 : index
#           %c32 = arith.constant 32 : index
#           %asyncToken_13, %valOut_14 = air.execute async  {
#             %10 = affine.apply #map()[%arg7]
#             air.execute_terminator %10 : index
#           } {id = 6 : i32} : (index)
#           %asyncToken_15, %valOut_16 = air.execute async  {
#             %10 = affine.apply #map()[%arg8]
#             air.execute_terminator %10 : index
#           } {id = 7 : i32} : (index)
#           %8 = air.wait_all async [%asyncToken_13, %asyncToken_15]
#           %9 = scf.for %arg14 = %c0_11 to %c64_12 step %c32 iter_args(%arg15 = %8) -> (!air.async.token) {
#             %asyncToken_17, %valOut_18 = air.execute async [%arg15]  : (!air.async.token) {
#               %15 = memref.alloc() : memref<32x32xbf16, 2>
#               air.execute_terminator %15 : memref<32x32xbf16, 2>
#             } {id = 8 : i32} : (memref<32x32xbf16, 2>)
#             %asyncToken_19, %valOut_20 = air.execute async [%arg15]  : (!air.async.token) {
#               %15 = memref.alloc() : memref<32x32xbf16, 2>
#               air.execute_terminator %15 : memref<32x32xbf16, 2>
#             } {id = 9 : i32} : (memref<32x32xbf16, 2>)
#             %asyncToken_21, %valOut_22 = air.execute async [%arg15]  : (!air.async.token) {
#               %15 = memref.alloc() : memref<32x32xbf16, 2>
#               air.execute_terminator %15 : memref<32x32xbf16, 2>
#             } {id = 10 : i32} : (memref<32x32xbf16, 2>)
#             %10 = air.dma_memcpy_nd async [%asyncToken_17, %arg15] (%valOut_18[] [] [], %arg11[%valOut_14, %arg14] [%c32, %c32] [%c64_12, %c1_10]) {id = 4 : i32} : (memref<32x32xbf16, 2>, memref<64x64xbf16, 1>)
#             %11 = air.dma_memcpy_nd async [%asyncToken_19, %arg15] (%valOut_20[] [] [], %arg12[%arg14, %valOut_16] [%c32, %c32] [%c64_12, %c1_10]) {id = 5 : i32} : (memref<32x32xbf16, 2>, memref<64x64xbf16, 1>)
#             %12 = air.dma_memcpy_nd async [%asyncToken_21, %arg15] (%valOut_22[] [] [], %arg13[%valOut_14, %valOut_16] [%c32, %c32] [%c64_12, %c1_10]) {id = 6 : i32} : (memref<32x32xbf16, 2>, memref<64x64xbf16, 1>)
#             %asyncToken_23 = air.execute async [%11, %12, %10]  : (!air.async.token, !air.async.token, !air.async.token) {
#               linalg.matmul {cast = #linalg.type_fn<cast_signed>} ins(%valOut_18, %valOut_20 : memref<32x32xbf16, 2>, memref<32x32xbf16, 2>) outs(%valOut_22 : memref<32x32xbf16, 2>)
#               air.execute_terminator
#             } {id = 11 : i32}
#             %13 = air.dma_memcpy_nd async [%asyncToken_23] (%arg13[%valOut_14, %valOut_16] [%c32, %c32] [%c64_12, %c1_10], %valOut_22[] [] []) {id = 7 : i32} : (memref<64x64xbf16, 1>, memref<32x32xbf16, 2>)
#             %asyncToken_24 = air.execute async [%asyncToken_23]  : (!air.async.token) {
#               memref.dealloc %valOut_18 : memref<32x32xbf16, 2>
#               air.execute_terminator
#             } {id = 12 : i32}
#             %asyncToken_25 = air.execute async [%asyncToken_23]  : (!air.async.token) {
#               memref.dealloc %valOut_20 : memref<32x32xbf16, 2>
#               air.execute_terminator
#             } {id = 13 : i32}
#             %asyncToken_26 = air.execute async [%13]  : (!air.async.token) {
#               memref.dealloc %valOut_22 : memref<32x32xbf16, 2>
#               air.execute_terminator
#             } {id = 14 : i32}
#             %14 = air.wait_all async [%asyncToken_24, %asyncToken_25, %asyncToken_26]
#             scf.yield %14 : !air.async.token
#           }
#           air.herd_terminator
#         }
#         %6 = air.dma_memcpy_nd async [%5] (%valOut[%arg3, %arg4] [%c64, %c64] [%c512, %c1], %valOut_6[] [] []) {id = 8 : i32} : (memref<512x512xbf16>, memref<64x64xbf16, 1>)
#         %asyncToken_7 = air.execute async [%5]  : (!air.async.token) {
#           memref.dealloc %valOut_2 : memref<64x64xbf16, 1>
#           air.execute_terminator
#         } {id = 15 : i32}
#         %asyncToken_8 = air.execute async [%5]  : (!air.async.token) {
#           memref.dealloc %valOut_4 : memref<64x64xbf16, 1>
#           air.execute_terminator
#         } {id = 16 : i32}
#         %asyncToken_9 = air.execute async [%6]  : (!air.async.token) {
#           memref.dealloc %valOut_6 : memref<64x64xbf16, 1>
#           air.execute_terminator
#         } {id = 17 : i32}
#         %7 = air.wait_all async [%asyncToken_7, %asyncToken_8, %asyncToken_9]
#         scf.yield %7 : !air.async.token
#       }
#       scf.reduce(%1)  : !air.async.token {
#       ^bb0(%arg5: !air.async.token, %arg6: !air.async.token):
#         %2 = air.wait_all async [%arg5, %arg6]
#         scf.reduce.return %2 : !air.async.token
#       }
#       scf.yield
#     }
#     return
#   }
# }

# %%
arch = {
  "clock": 1000000000,
  "cores": 1,
  "datatype": {
    "bytes": 2,
    "name": "fp16"
  },
  "devicename": "testdevice",
  "interfaces": [
    {
      "bytes_per_second": 100000000000,
      "dst": 1,
      "src": 0
    },
    {
      "bytes_per_second": 100000000000,
      "dst": 0,
      "src": 1
    },
    {
      "bytes_per_second": 100000000000,
      "dst": 2,
      "src": 0
    },
    {
      "bytes_per_second": 100000000000,
      "dst": 0,
      "src": 2
    },
    {
      "bytes_per_second": 100000000000,
      "dst": 2,
      "src": 1
    },
    {
      "bytes_per_second": 100000000000,
      "dst": 1,
      "src": 2
    }
  ],
  "kernels": {
    "linalg.copy": {
      "efficiency": 1,
      "name": "linalg.copy"
    },
    "linalg.fill": {
      "efficiency": 1,
      "name": "linalg.fill"
    },
    "linalg.matmul": {
      "efficiency": 1,
      "name": "linalg.matmul"
    }
  },
  "ops_per_core_per_cycle": 512,
  "num_herd_slots": 1,
  "num_dispatch_queues": 1
}

# %%
runner = air.compiler.util.Runner(arch)
trace = runner.run(air_module, "matmul")
# Out:
# Finished at time 408136

# %%
arch["num_herd_slots"] = 4
arch["num_dispatch_queues"] = 8
runner = air.compiler.util.Runner(arch)
trace = runner.run(air_module, "matmul")
# Out:
# Finished at time 50751

# %%
with open("trace.out", "w") as f:
   f.write(trace)

# %% [markdown]
# Copyright (C) 2022, Advanced Micro Devices, Inc. All rights reserved.
#
# SPDX-License-Identifier: MIT

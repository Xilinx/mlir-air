# %%
import air.compiler.util

from air.mlir.dialects import func
from air.mlir.dialects import linalg
from air.mlir.ir import *
import air.mlir.passmanager

import sys

# %%
def matmul_on_tensors(m, n, k, dtype):
    module = Module.create()
    with InsertionPoint(module.body):
        @func.FuncOp.from_py_func(
            RankedTensorType.get((m, k), dtype), RankedTensorType.get((k, n), dtype),
            RankedTensorType.get((m, n), dtype))
        def matmul(lhs, rhs, out):
            linalg.matmul(lhs, rhs, outs=[out])
    return module

# %%
with air.mlir.ir.Context(), Location.unknown():

    air_module = matmul_on_tensors(512, 512, 512, BF16Type.get())
    
    # convert linalg on tensors to linalg on memrefs
    pm = air.mlir.passmanager.PassManager.parse(air.compiler.util.LINALG_TENSOR_TO_MEMREF_PIPELINE)
    pm.run(air_module)

    # tile and map to air
    pipeline = "builtin.module("+",".join([
        "air-linalg-codegen{l2-tile-size=128,128,128 l2-promote=true l1-tile-size=32,32,32 l1-promote=true}",
        "canonicalize", "cse",
        "air-par-to-herd{depth=1}",
        "air-copy-to-dma",
        "air-par-to-launch{has-air-segment=true}",
        "canonicalize", "cse",
    ])+')'
    pm = air.mlir.passmanager.PassManager.parse(pipeline)
    pm.run(air_module)
    
    print ("\nAIR Dialect Module\n")
    print (air_module)

    # generate dependency information for runner
    pipeline = "builtin.module("+",".join([
        "air-dependency",
        "air-dependency-schedule-opt",
        "air-specialize-dma-broadcast",
        "air-dma-to-channel",
        "canonicalize", "cse",
        "air-dependency-canonicalize",
        "air-dependency-parse-graph{output-dir=dot_graphs/}",
        "canonicalize", "cse",
        "air-place-herds{num-rows=4 num-cols=4 row-anchor=0 col-anchor=0}",
        "air-label-scf-for-to-ping-pong",
        "air-ping-pong-transform"
    ])+')'
    pm = air.mlir.passmanager.PassManager.parse(pipeline)
    pm.run(air_module)

    print ("\nAIR Dialect Module (async)\n")
    print (air_module)
# Out:
# AIR Dialect Module
#
# #map = affine_map<()[s0] -> (s0 * 128)>
# #map1 = affine_map<()[s0] -> (s0 * 32)>
# module {
#   func.func @matmul(%arg0: memref<512x512xbf16>, %arg1: memref<512x512xbf16>, %arg2: memref<512x512xbf16>) {
#     %c4 = arith.constant 4 : index
#     %alloc = memref.alloc() {alignment = 64 : i64} : memref<512x512xbf16>
#     memref.copy %arg2, %alloc : memref<512x512xbf16> to memref<512x512xbf16>
#     air.launch (%arg3, %arg4) in (%arg5=%c4, %arg6=%c4) args(%arg7=%arg0, %arg8=%arg1, %arg9=%alloc) : memref<512x512xbf16>, memref<512x512xbf16>, memref<512x512xbf16> {
#       air.segment  args(%arg10=%arg3, %arg11=%arg4, %arg12=%arg7, %arg13=%arg8, %arg14=%arg9) : index, index, memref<512x512xbf16>, memref<512x512xbf16>, memref<512x512xbf16> {
#         %c1 = arith.constant 1 : index
#         %c4_0 = arith.constant 4 : index
#         %c0 = arith.constant 0 : index
#         %c512 = arith.constant 512 : index
#         %c128 = arith.constant 128 : index
#         %0 = affine.apply #map()[%arg10]
#         %1 = affine.apply #map()[%arg11]
#         scf.for %arg15 = %c0 to %c512 step %c128 {
#           %alloc_1 = memref.alloc() : memref<128x128xbf16, 1>
#           %alloc_2 = memref.alloc() : memref<128x128xbf16, 1>
#           %alloc_3 = memref.alloc() : memref<128x128xbf16, 1>
#           air.dma_memcpy_nd (%alloc_1[] [] [], %arg12[%0, %arg15] [%c128, %c128] [%c512, %c1]) {id = 1 : i32} : (memref<128x128xbf16, 1>, memref<512x512xbf16>)
#           air.dma_memcpy_nd (%alloc_2[] [] [], %arg13[%arg15, %1] [%c128, %c128] [%c512, %c1]) {id = 2 : i32} : (memref<128x128xbf16, 1>, memref<512x512xbf16>)
#           air.dma_memcpy_nd (%alloc_3[] [] [], %arg14[%0, %1] [%c128, %c128] [%c512, %c1]) {id = 3 : i32} : (memref<128x128xbf16, 1>, memref<512x512xbf16>)
#           air.herd @herd_0  tile (%arg16, %arg17) in (%arg18=%c4_0, %arg19=%c4_0) args(%arg20=%alloc_1, %arg21=%alloc_2, %arg22=%alloc_3) : memref<128x128xbf16, 1>, memref<128x128xbf16, 1>, memref<128x128xbf16, 1> {
#             %c1_4 = arith.constant 1 : index
#             %c0_5 = arith.constant 0 : index
#             %c128_6 = arith.constant 128 : index
#             %c32 = arith.constant 32 : index
#             %2 = affine.apply #map1()[%arg16]
#             %3 = affine.apply #map1()[%arg17]
#             scf.for %arg23 = %c0_5 to %c128_6 step %c32 {
#               %alloc_7 = memref.alloc() : memref<32x32xbf16, 2>
#               %alloc_8 = memref.alloc() : memref<32x32xbf16, 2>
#               %alloc_9 = memref.alloc() : memref<32x32xbf16, 2>
#               air.dma_memcpy_nd (%alloc_7[] [] [], %arg20[%2, %arg23] [%c32, %c32] [%c128_6, %c1_4]) {id = 4 : i32} : (memref<32x32xbf16, 2>, memref<128x128xbf16, 1>)
#               air.dma_memcpy_nd (%alloc_8[] [] [], %arg21[%arg23, %3] [%c32, %c32] [%c128_6, %c1_4]) {id = 5 : i32} : (memref<32x32xbf16, 2>, memref<128x128xbf16, 1>)
#               air.dma_memcpy_nd (%alloc_9[] [] [], %arg22[%2, %3] [%c32, %c32] [%c128_6, %c1_4]) {id = 6 : i32} : (memref<32x32xbf16, 2>, memref<128x128xbf16, 1>)
#               linalg.matmul {cast = #linalg.type_fn<cast_signed>} ins(%alloc_7, %alloc_8 : memref<32x32xbf16, 2>, memref<32x32xbf16, 2>) outs(%alloc_9 : memref<32x32xbf16, 2>)
#               air.dma_memcpy_nd (%arg22[%2, %3] [%c32, %c32] [%c128_6, %c1_4], %alloc_9[] [] []) {id = 7 : i32} : (memref<128x128xbf16, 1>, memref<32x32xbf16, 2>)
#               memref.dealloc %alloc_7 : memref<32x32xbf16, 2>
#               memref.dealloc %alloc_8 : memref<32x32xbf16, 2>
#               memref.dealloc %alloc_9 : memref<32x32xbf16, 2>
#             }
#             air.herd_terminator
#           }
#           air.dma_memcpy_nd (%arg14[%0, %1] [%c128, %c128] [%c512, %c1], %alloc_3[] [] []) {id = 8 : i32} : (memref<512x512xbf16>, memref<128x128xbf16, 1>)
#           memref.dealloc %alloc_1 : memref<128x128xbf16, 1>
#           memref.dealloc %alloc_2 : memref<128x128xbf16, 1>
#           memref.dealloc %alloc_3 : memref<128x128xbf16, 1>
#         }
#         air.segment_terminator
#       }
#       air.launch_terminator
#     }
#     return
#   }
# }
#
#
# AIR Dialect Module (async)
#
# #map = affine_map<()[s0] -> (s0 * 128)>
# #map1 = affine_map<()[s0] -> (s0 * 32)>
# #set = affine_set<()[s0, s1] : (s0 == 0, s1 >= 0, -s1 + 3 >= 0)>
# #set1 = affine_set<()[s0, s1] : (s0 - 1 == 0, s1 >= 0, -s1 + 3 >= 0)>
# #set2 = affine_set<()[s0, s1] : (s0 - 2 == 0, s1 >= 0, -s1 + 3 >= 0)>
# #set3 = affine_set<()[s0, s1] : (s0 >= 0, -s0 + 3 >= 0, s1 == 0)>
# #set4 = affine_set<()[s0, s1] : (s0 >= 0, -s0 + 3 >= 0, s1 - 1 == 0)>
# #set5 = affine_set<()[s0, s1] : (s0 >= 0, -s0 + 3 >= 0, s1 - 2 == 0)>
# module {
#   air.channel @channel_13 [1, 1]
#   air.channel @channel_12 [4, 4]
#   air.channel @channel_11 [4, 4]
#   air.channel @channel_10 [1, 1]
#   air.channel @channel_9 [1, 1]
#   air.channel @channel_8 [1, 1]
#   air.channel @channel_7 [1, 1] {broadcast_shape = [4, 1]}
#   air.channel @channel_6 [1, 1] {broadcast_shape = [4, 1]}
#   air.channel @channel_5 [1, 1] {broadcast_shape = [4, 1]}
#   air.channel @channel_4 [1, 1] {broadcast_shape = [4, 1]}
#   air.channel @channel_3 [1, 1] {broadcast_shape = [1, 4]}
#   air.channel @channel_2 [1, 1] {broadcast_shape = [1, 4]}
#   air.channel @channel_1 [1, 1] {broadcast_shape = [1, 4]}
#   air.channel @channel_0 [1, 1] {broadcast_shape = [1, 4]}
#   func.func @matmul(%arg0: memref<512x512xbf16>, %arg1: memref<512x512xbf16>, %arg2: memref<512x512xbf16>) {
#     %c4 = arith.constant 4 : index
#     %async_token, %results = air.execute -> (memref<512x512xbf16>) {
#       %alloc = memref.alloc() {alignment = 64 : i64} : memref<512x512xbf16>
#       air.execute_terminator %alloc : memref<512x512xbf16>
#     }
#     %async_token_0 = air.execute [%async_token] {
#       memref.copy %arg2, %results : memref<512x512xbf16> to memref<512x512xbf16>
#     }
#     %0 = air.launch async [%async_token_0] (%arg3, %arg4) in (%arg5=%c4, %arg6=%c4) args(%arg7=%arg0, %arg8=%arg1, %arg9=%results) : memref<512x512xbf16>, memref<512x512xbf16>, memref<512x512xbf16> {
#       %c0 = arith.constant 0 : index
#       %c1 = arith.constant 1 : index
#       %c512 = arith.constant 512 : index
#       %c128 = arith.constant 128 : index
#       %async_token_1, %results_2 = air.execute -> (index) {
#         %8 = affine.apply #map()[%arg3]
#         air.execute_terminator %8 : index
#       }
#       %async_token_3, %results_4 = air.execute -> (index) {
#         %8 = affine.apply #map()[%arg4]
#         air.execute_terminator %8 : index
#       }
#       %1 = air.channel.put async [%async_token_3, %async_token_1]  @channel_8[] (%arg9[%results_2, %results_4] [%c128, %c128] [%c512, %c1]) : (memref<512x512xbf16>)
#       %async_token_5, %results_6 = air.execute -> (index) {
#         %8 = affine.apply #map()[%arg3]
#         air.execute_terminator %8 : index
#       }
#       %2 = air.wait_all async
#       %3 = scf.for %arg10 = %c0 to %c512 step %c128 iter_args(%arg11 = %2) -> (!air.async.token) {
#         %8 = air.channel.put async [%arg11, %async_token_5]  @channel_9[] (%arg7[%results_6, %arg10] [%c128, %c128] [%c512, %c1]) : (memref<512x512xbf16>)
#         scf.yield %8 : !air.async.token
#       }
#       %async_token_7, %results_8 = air.execute -> (index) {
#         %8 = affine.apply #map()[%arg4]
#         air.execute_terminator %8 : index
#       }
#       %4 = air.wait_all async
#       %5 = scf.for %arg10 = %c0 to %c512 step %c128 iter_args(%arg11 = %4) -> (!air.async.token) {
#         %8 = air.channel.put async [%arg11, %async_token_7]  @channel_10[] (%arg8[%arg10, %results_8] [%c128, %c128] [%c512, %c1]) : (memref<512x512xbf16>)
#         scf.yield %8 : !air.async.token
#       }
#       %async_token_9, %results_10 = air.execute -> (index) {
#         %8 = affine.apply #map()[%arg3]
#         air.execute_terminator %8 : index
#       }
#       %async_token_11, %results_12 = air.execute -> (index) {
#         %8 = affine.apply #map()[%arg4]
#         air.execute_terminator %8 : index
#       }
#       %6 = air.channel.get async [%async_token_11, %async_token_9]  @channel_13[] (%arg9[%results_10, %results_12] [%c128, %c128] [%c512, %c1]) : (memref<512x512xbf16>)
#       %7 = air.segment async  attributes {x_loc = 0 : i64, x_size = 4 : i64, y_loc = 0 : i64, y_size = 4 : i64} {
#         %c256 = arith.constant 256 : index
#         %c96 = arith.constant 96 : index
#         %c64 = arith.constant 64 : index
#         %c32 = arith.constant 32 : index
#         %c1_13 = arith.constant 1 : index
#         %c4_14 = arith.constant 4 : index
#         %c0_15 = arith.constant 0 : index
#         %c512_16 = arith.constant 512 : index
#         %c128_17 = arith.constant 128 : index
#         %8 = air.wait_all async
#         %async_token_18, %results_19 = air.execute -> (memref<128x128xbf16, 1>) {
#           %alloc = memref.alloc() : memref<128x128xbf16, 1>
#           air.execute_terminator %alloc : memref<128x128xbf16, 1>
#         }
#         %9 = air.channel.get async [%async_token_18, %8]  @channel_8[] (%results_19[] [] []) : (memref<128x128xbf16, 1>)
#         %10 = scf.for %arg10 = %c0_15 to %c512_16 step %c128_17 iter_args(%arg11 = %9) -> (!air.async.token) {
#           %13 = air.herd @herd_0 async [%arg11]  tile (%arg12, %arg13) in (%arg14=%c4_14, %arg15=%c4_14) attributes {x_loc = 0 : i64, y_loc = 0 : i64} {
#             %c64_33 = arith.constant 64 : index
#             %c0_34 = arith.constant 0 : index
#             %c128_35 = arith.constant 128 : index
#             %17 = air.wait_all async
#             %async_token_36, %results_37 = air.execute -> (memref<32x32xbf16, 2>) {
#               %alloc = memref.alloc() : memref<32x32xbf16, 2>
#               air.execute_terminator %alloc : memref<32x32xbf16, 2>
#             }
#             %18 = air.channel.get async [%async_token_36, %17]  @channel_11[%arg12, %arg13] (%results_37[] [] []) : (memref<32x32xbf16, 2>)
#             %async_token_38, %results_39 = air.execute [%18] -> (memref<32x32xbf16, 2>) {
#               %alloc = memref.alloc() : memref<32x32xbf16, 2>
#               air.execute_terminator %alloc : memref<32x32xbf16, 2>
#             }
#             %async_token_40, %results_41 = air.execute [%async_token_38] -> (memref<32x32xbf16, 2>) {
#               %alloc = memref.alloc() : memref<32x32xbf16, 2>
#               air.execute_terminator %alloc : memref<32x32xbf16, 2>
#             }
#             %async_token_42, %results_43 = air.execute [%async_token_40] -> (memref<32x32xbf16, 2>) {
#               %alloc = memref.alloc() : memref<32x32xbf16, 2>
#               air.execute_terminator %alloc : memref<32x32xbf16, 2>
#             }
#             %async_token_44, %results_45 = air.execute [%async_token_40] -> (memref<32x32xbf16, 2>) {
#               %alloc = memref.alloc() : memref<32x32xbf16, 2>
#               air.execute_terminator %alloc : memref<32x32xbf16, 2>
#             }
#             %19:4 = scf.for %arg16 = %c0_34 to %c128_35 step %c64_33 iter_args(%arg17 = %async_token_42, %arg18 = %async_token_44, %arg19 = %async_token_44, %arg20 = %async_token_44) -> (!air.async.token, !air.async.token, !air.async.token, !air.async.token) {
#               %21 = affine.if #set()[%arg12, %arg13] -> !air.async.token {
#                 %26 = air.channel.get async [%arg20, %async_token_42, %arg17]  @channel_0[%arg12, %arg13] (%results_43[] [] []) : (memref<32x32xbf16, 2>)
#                 affine.yield %26 : !air.async.token
#               } else {
#                 %26 = affine.if #set1()[%arg12, %arg13] -> !air.async.token {
#                   %27 = air.channel.get async [%arg20, %async_token_42, %arg17]  @channel_1[%arg12, %arg13] (%results_43[] [] []) : (memref<32x32xbf16, 2>)
#                   affine.yield %27 : !air.async.token
#                 } else {
#                   %27 = affine.if #set2()[%arg12, %arg13] -> !air.async.token {
#                     %28 = air.channel.get async [%arg20, %async_token_42, %arg17]  @channel_2[%arg12, %arg13] (%results_43[] [] []) : (memref<32x32xbf16, 2>)
#                     affine.yield %28 : !air.async.token
#                   } else {
#                     %28 = air.channel.get async [%arg20, %async_token_42, %arg17]  @channel_3[%arg12, %arg13] (%results_43[] [] []) : (memref<32x32xbf16, 2>)
#                     affine.yield %28 : !air.async.token
#                   }
#                   affine.yield %27 : !air.async.token
#                 }
#                 affine.yield %26 : !air.async.token
#               }
#               %22 = affine.if #set3()[%arg12, %arg13] -> !air.async.token {
#                 %26 = air.channel.get async [%arg20, %async_token_44, %arg17]  @channel_4[%arg12, %arg13] (%results_45[] [] []) : (memref<32x32xbf16, 2>)
#                 affine.yield %26 : !air.async.token
#               } else {
#                 %26 = affine.if #set4()[%arg12, %arg13] -> !air.async.token {
#                   %27 = air.channel.get async [%arg20, %async_token_44, %arg17]  @channel_5[%arg12, %arg13] (%results_45[] [] []) : (memref<32x32xbf16, 2>)
#                   affine.yield %27 : !air.async.token
#                 } else {
#                   %27 = affine.if #set5()[%arg12, %arg13] -> !air.async.token {
#                     %28 = air.channel.get async [%arg20, %async_token_44, %arg17]  @channel_6[%arg12, %arg13] (%results_45[] [] []) : (memref<32x32xbf16, 2>)
#                     affine.yield %28 : !air.async.token
#                   } else {
#                     %28 = air.channel.get async [%arg20, %async_token_44, %arg17]  @channel_7[%arg12, %arg13] (%results_45[] [] []) : (memref<32x32xbf16, 2>)
#                     affine.yield %28 : !air.async.token
#                   }
#                   affine.yield %27 : !air.async.token
#                 }
#                 affine.yield %26 : !air.async.token
#               }
#               %async_token_51 = air.execute [%arg19, %22, %21] {
#                 linalg.matmul {cast = #linalg.type_fn<cast_signed>} ins(%results_43, %results_45 : memref<32x32xbf16, 2>, memref<32x32xbf16, 2>) outs(%results_37 : memref<32x32xbf16, 2>)
#               }
#               %23 = affine.if #set()[%arg12, %arg13] -> !air.async.token {
#                 %26 = air.channel.get async [%22, %21, %arg18]  @channel_0[%arg12, %arg13] (%results_41[] [] []) : (memref<32x32xbf16, 2>)
#                 affine.yield %26 : !air.async.token
#               } else {
#                 %26 = affine.if #set1()[%arg12, %arg13] -> !air.async.token {
#                   %27 = air.channel.get async [%22, %21, %arg18]  @channel_1[%arg12, %arg13] (%results_41[] [] []) : (memref<32x32xbf16, 2>)
#                   affine.yield %27 : !air.async.token
#                 } else {
#                   %27 = affine.if #set2()[%arg12, %arg13] -> !air.async.token {
#                     %28 = air.channel.get async [%22, %21, %arg18]  @channel_2[%arg12, %arg13] (%results_41[] [] []) : (memref<32x32xbf16, 2>)
#                     affine.yield %28 : !air.async.token
#                   } else {
#                     %28 = air.channel.get async [%22, %21, %arg18]  @channel_3[%arg12, %arg13] (%results_41[] [] []) : (memref<32x32xbf16, 2>)
#                     affine.yield %28 : !air.async.token
#                   }
#                   affine.yield %27 : !air.async.token
#                 }
#                 affine.yield %26 : !air.async.token
#               }
#               %24 = affine.if #set3()[%arg12, %arg13] -> !air.async.token {
#                 %26 = air.channel.get async [%22, %21, %arg18]  @channel_4[%arg12, %arg13] (%results_39[] [] []) : (memref<32x32xbf16, 2>)
#                 affine.yield %26 : !air.async.token
#               } else {
#                 %26 = affine.if #set4()[%arg12, %arg13] -> !air.async.token {
#                   %27 = air.channel.get async [%22, %21, %arg18]  @channel_5[%arg12, %arg13] (%results_39[] [] []) : (memref<32x32xbf16, 2>)
#                   affine.yield %27 : !air.async.token
#                 } else {
#                   %27 = affine.if #set5()[%arg12, %arg13] -> !air.async.token {
#                     %28 = air.channel.get async [%22, %21, %arg18]  @channel_6[%arg12, %arg13] (%results_39[] [] []) : (memref<32x32xbf16, 2>)
#                     affine.yield %28 : !air.async.token
#                   } else {
#                     %28 = air.channel.get async [%22, %21, %arg18]  @channel_7[%arg12, %arg13] (%results_39[] [] []) : (memref<32x32xbf16, 2>)
#                     affine.yield %28 : !air.async.token
#                   }
#                   affine.yield %27 : !air.async.token
#                 }
#                 affine.yield %26 : !air.async.token
#               }
#               %async_token_52 = air.execute [%async_token_51, %24, %23] {
#                 linalg.matmul {cast = #linalg.type_fn<cast_signed>} ins(%results_41, %results_39 : memref<32x32xbf16, 2>, memref<32x32xbf16, 2>) outs(%results_37 : memref<32x32xbf16, 2>)
#               }
#               %25 = air.wait_all async [%23, %24]
#               scf.yield %async_token_51, %async_token_52, %async_token_52, %25 : !air.async.token, !air.async.token, !air.async.token, !air.async.token
#             }
#             %async_token_46 = air.execute [%19#1] {
#               memref.dealloc %results_43 : memref<32x32xbf16, 2>
#             }
#             %async_token_47 = air.execute [%19#1] {
#               memref.dealloc %results_45 : memref<32x32xbf16, 2>
#             }
#             %async_token_48 = air.execute [%19#1] {
#               memref.dealloc %results_41 : memref<32x32xbf16, 2>
#             }
#             %async_token_49 = air.execute [%19#1] {
#               memref.dealloc %results_39 : memref<32x32xbf16, 2>
#             }
#             %20 = air.channel.put async [%19#1]  @channel_12[%arg12, %arg13] (%results_37[] [] []) : (memref<32x32xbf16, 2>)
#             %async_token_50 = air.execute [%20] {
#               memref.dealloc %results_37 : memref<32x32xbf16, 2>
#             }
#             air.herd_terminator
#           }
#           %14 = scf.parallel (%arg12, %arg13) = (%c0_15, %c0_15) to (%c4_14, %c4_14) step (%c1_13, %c1_13) init (%arg11) -> !air.async.token {
#             %async_token_33, %results_34 = air.execute -> (index) {
#               %18 = affine.apply #map1()[%arg12]
#               air.execute_terminator %18 : index
#             }
#             %async_token_35, %results_36 = air.execute -> (index) {
#               %18 = affine.apply #map1()[%arg13]
#               air.execute_terminator %18 : index
#             }
#             %17 = air.channel.put async [%async_token_35, %async_token_33, %arg11]  @channel_11[%arg12, %arg13] (%results_19[%results_34, %results_36] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.reduce(%17)  : !air.async.token {
#             ^bb0(%arg14: !air.async.token, %arg15: !air.async.token):
#               %18 = air.wait_all async [%arg14, %arg15]
#               scf.reduce.return %18 : !air.async.token
#             }
#             scf.yield
#           }
#           %15 = scf.parallel (%arg12, %arg13) = (%c0_15, %c0_15) to (%c4_14, %c4_14) step (%c1_13, %c1_13) init (%arg11) -> !air.async.token {
#             %async_token_33, %results_34 = air.execute -> (index) {
#               %18 = affine.apply #map1()[%arg12]
#               air.execute_terminator %18 : index
#             }
#             %async_token_35, %results_36 = air.execute -> (index) {
#               %18 = affine.apply #map1()[%arg13]
#               air.execute_terminator %18 : index
#             }
#             %17 = air.channel.get async [%async_token_35, %async_token_33, %arg11]  @channel_12[%arg12, %arg13] (%results_19[%results_34, %results_36] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.reduce(%17)  : !air.async.token {
#             ^bb0(%arg14: !air.async.token, %arg15: !air.async.token):
#               %18 = air.wait_all async [%arg14, %arg15]
#               scf.reduce.return %18 : !air.async.token
#             }
#             scf.yield
#           }
#           %16 = air.wait_all async [%13, %14, %15]
#           scf.yield %16 : !air.async.token
#         }
#         %async_token_20, %results_21 = air.execute [%9] -> (memref<128x128xbf16, 1>) {
#           %alloc = memref.alloc() : memref<128x128xbf16, 1>
#           air.execute_terminator %alloc : memref<128x128xbf16, 1>
#         }
#         %async_token_22, %results_23 = air.execute [%async_token_20] -> (memref<128x128xbf16, 1>) {
#           %alloc = memref.alloc() : memref<128x128xbf16, 1>
#           air.execute_terminator %alloc : memref<128x128xbf16, 1>
#         }
#         %async_token_24, %results_25 = air.execute [%async_token_22] -> (memref<128x128xbf16, 1>) {
#           %alloc = memref.alloc() : memref<128x128xbf16, 1>
#           air.execute_terminator %alloc : memref<128x128xbf16, 1>
#         }
#         %async_token_26, %results_27 = air.execute [%async_token_22] -> (memref<128x128xbf16, 1>) {
#           %alloc = memref.alloc() : memref<128x128xbf16, 1>
#           air.execute_terminator %alloc : memref<128x128xbf16, 1>
#         }
#         %11:4 = scf.for %arg10 = %c0_15 to %c512_16 step %c256 iter_args(%arg11 = %async_token_24, %arg12 = %async_token_26, %arg13 = %async_token_26, %arg14 = %async_token_26) -> (!air.async.token, !air.async.token, !air.async.token, !air.async.token) {
#           %13 = air.channel.get async [%arg14, %async_token_24, %arg11]  @channel_9[] (%results_25[] [] []) : (memref<128x128xbf16, 1>)
#           %14 = air.channel.get async [%arg14, %async_token_26, %arg11]  @channel_10[] (%results_27[] [] []) : (memref<128x128xbf16, 1>)
#           %15 = air.wait_all async [%arg13, %13]
#           %16 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %15) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_0[] (%results_25[%c0_15, %arg15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %17 = air.wait_all async [%arg13, %13]
#           %18 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %17) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_1[] (%results_25[%c32, %arg15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %19 = air.wait_all async [%arg13, %13]
#           %20 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %19) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_2[] (%results_25[%c64, %arg15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %21 = air.wait_all async [%arg13, %13]
#           %22 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %21) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_3[] (%results_25[%c96, %arg15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %23 = air.wait_all async [%arg13, %14]
#           %24 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %23) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_4[] (%results_27[%arg15, %c0_15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %25 = air.wait_all async [%arg13, %14]
#           %26 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %25) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_5[] (%results_27[%arg15, %c32] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %27 = air.wait_all async [%arg13, %14]
#           %28 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %27) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_6[] (%results_27[%arg15, %c64] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %29 = air.wait_all async [%arg13, %14]
#           %30 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %29) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_7[] (%results_27[%arg15, %c96] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %31 = air.wait_all async [%13, %14, %30, %28, %26, %24, %22, %20, %18, %16]
#           %32 = air.channel.get async [%14, %13, %arg12]  @channel_9[] (%results_23[] [] []) : (memref<128x128xbf16, 1>)
#           %33 = air.channel.get async [%14, %13, %arg12]  @channel_10[] (%results_21[] [] []) : (memref<128x128xbf16, 1>)
#           %34 = air.wait_all async [%31, %32]
#           %35 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %34) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_0[] (%results_23[%c0_15, %arg15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %36 = air.wait_all async [%31, %32]
#           %37 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %36) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_1[] (%results_23[%c32, %arg15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %38 = air.wait_all async [%31, %32]
#           %39 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %38) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_2[] (%results_23[%c64, %arg15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %40 = air.wait_all async [%31, %32]
#           %41 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %40) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_3[] (%results_23[%c96, %arg15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %42 = air.wait_all async [%31, %33]
#           %43 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %42) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_4[] (%results_21[%arg15, %c0_15] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %44 = air.wait_all async [%31, %33]
#           %45 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %44) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_5[] (%results_21[%arg15, %c32] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %46 = air.wait_all async [%31, %33]
#           %47 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %46) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_6[] (%results_21[%arg15, %c64] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %48 = air.wait_all async [%31, %33]
#           %49 = scf.for %arg15 = %c0_15 to %c128_17 step %c32 iter_args(%arg16 = %48) -> (!air.async.token) {
#             %52 = air.channel.put async [%arg16]  @channel_7[] (%results_21[%arg15, %c96] [%c32, %c32] [%c128_17, %c1_13]) : (memref<128x128xbf16, 1>)
#             scf.yield %52 : !air.async.token
#           }
#           %50 = air.wait_all async [%32, %33, %49, %47, %45, %43, %41, %39, %37, %35]
#           %51 = air.wait_all async [%32, %33]
#           scf.yield %31, %50, %50, %51 : !air.async.token, !air.async.token, !air.async.token, !air.async.token
#         }
#         %async_token_28 = air.execute [%11#1] {
#           memref.dealloc %results_25 : memref<128x128xbf16, 1>
#         }
#         %async_token_29 = air.execute [%11#1] {
#           memref.dealloc %results_27 : memref<128x128xbf16, 1>
#         }
#         %async_token_30 = air.execute [%11#1] {
#           memref.dealloc %results_23 : memref<128x128xbf16, 1>
#         }
#         %async_token_31 = air.execute [%11#1] {
#           memref.dealloc %results_21 : memref<128x128xbf16, 1>
#         }
#         %12 = air.channel.put async [%10, %11#1]  @channel_13[] (%results_19[] [] []) : (memref<128x128xbf16, 1>)
#         %async_token_32 = air.execute [%12] {
#           memref.dealloc %results_19 : memref<128x128xbf16, 1>
#         }
#         air.segment_terminator
#       }
#       air.launch_terminator
#     }
#     return
#   }
# }

# %%
arch = {
    "clock": 1000000000,
    "cores": 1,
    "datatypes": [
        {
        "bytes": 1,
        "name": "i8"
        },
        {
        "bytes": 2,
        "name": "bf16"
        },
        {
        "bytes": 4,
        "name": "i32"
        }
    ],
    "devicename": "testdevice",
    "kernels": {
        "linalg.copy": {
            "datatypes": {
                "i8": {
                    "ops_per_core_per_cycle": 32,
                    "efficiency": 1
                },
                "bf16": {
                    "ops_per_core_per_cycle": 32,
                    "efficiency": 1
                },
                "i32": {
                    "ops_per_core_per_cycle": 16,
                    "efficiency": 1
                }
            },
            "name": "linalg.copy"
        },
        "linalg.fill": {
            "datatypes": {
                "i8": {
                    "ops_per_core_per_cycle": 32,
                    "efficiency": 1
                },
                "bf16": {
                    "ops_per_core_per_cycle": 32,
                    "efficiency": 1
                },
                "i32": {
                    "ops_per_core_per_cycle": 16,
                    "efficiency": 1
                }
            },
            "name": "linalg.fill"
        },
        "linalg.generic": {
            "datatypes": {
                "i8": {
                    "ops_per_core_per_cycle": 1,
                    "efficiency": 1
                },
                "bf16": {
                    "ops_per_core_per_cycle": 1,
                    "efficiency": 1
                },
                "i32": {
                    "ops_per_core_per_cycle": 1,
                    "efficiency": 1
                }
            },
            "name": "linalg.generic"
        },
        "linalg.matmul": {
            "datatypes": {
                "i8": {
                    "macs_per_core_per_cycle": 256,
                    "efficiency": 1
                },
                "bf16": {
                    "macs_per_core_per_cycle": 128,
                    "efficiency": 1
                },
                "i32": {
                    "macs_per_core_per_cycle": 32,
                    "efficiency": 1
                }
            },
            "name": "linalg.matmul"
        }
    },
    "dus": {
        "count": [4, 4],
        "memory": {
            "memory_space": "L2",
            "bytes": 524288
        },
        "ports": {
            "outbound": {
                "count": 6,
                "bytes_per_second": 4000000000
            },
            "inbound": {
                "count": 6,
                "bytes_per_second": 4000000000
            }
        },
        "tiles": {
            "count": [1, 4],
            "memory": {
                "memory_space": "L1",
                "bytes": 65536
            },
            "ports": {
                "outbound": {
                    "count": 2,
                    "bytes_per_second": 4000000000
                },
                "inbound": {
                    "count": 2,
                    "bytes_per_second": 4000000000
                }
            }
        }
    },
    "noc": {
        "outbound": {
            "count": 4,
            "bytes_per_second": 4000000000
        },
        "inbound": {
            "count": 4,
            "bytes_per_second": 4000000000
        }
    }
  }

# %%
runner = air.compiler.util.Runner(arch, "trace.out", "core")
trace = runner.run(air_module, "matmul")
# Out:
# Latency: 831.857us

# %% [markdown]
# Copyright (C) 2022, Advanced Micro Devices, Inc. All rights reserved.
#
# SPDX-License-Identifier: MIT
